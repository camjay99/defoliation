# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import geopandas as gpd
import matplotlib as plt
import matplotlib.patches as mpatches
import numpy as np
import pandas as pd
import rasterio as rio
from rasterio.transform import array_bounds
from rasterio.warp import calculate_default_transform, reproject, Resampling
import ultraplot as uplt

# %%
prcp_anom_cols = [f'prcp_anom_{i}' for i in range(1, 25)]
tmax_anom_cols = [f'tmax_anom_{i}' for i in range(1, 25)]
prcp_mean_cols = [f'prcp_mean_{i}' for i in range(1, 25)]
tmax_mean_cols = [f'tmax_mean_{i}' for i in range(1, 25)]

# %%
df_2020 = gpd.read_file('./Data/TimeImpacts/time_lags_months_2020.geojson')

df_2021 = gpd.read_file('./Data/TimeImpacts/time_lags_months_2021.geojson')

df_2022 = gpd.read_file('./Data/TimeImpacts/time_lags_months_2022.geojson')

df_2023 = gpd.read_file('./Data/TimeImpacts/time_lags_months_2023.geojson')

# %%
def calc_window(df, cols, prefix, i, j):
    # Aggregates specified columns. Return new dataframe and name of column appended.
    agg = df[cols[i]].copy()
    for k in range(i+1, j+1):
        agg += df[cols[k]]
    return agg.rename(f'{prefix}_{i+1}_{j+1}'), f'{prefix}_{i+1}_{j+1}'

# %%
df_2021['prcp_anom_10_12'] = calc_window(df_2021, prcp_anom_cols, 'prcp_anom', 9, 11)[0]
df_2021['tmax_anom_10_11'] = calc_window(df_2021, tmax_anom_cols, 'tmax_anom', 9, 10)[0]

df_2023['prcp_anom_10_12'] = calc_window(df_2023, prcp_anom_cols, 'prcp_anom', 9, 11)[0]
df_2023['tmax_anom_10_11'] = calc_window(df_2023, tmax_anom_cols, 'tmax_anom', 9, 10)[0]

# %%
print(df_2021['prcp_anom_10_12'].min())
print(df_2021['prcp_anom_10_12'].max())

print(df_2023['prcp_anom_10_12'].min())
print(df_2023['prcp_anom_10_12'].max())
# Out:
# -140.75191758366773
# 165.34609138241632
# -215.52677049114743
# 115.67410915573849

# %%
print(df_2021['tmax_anom_10_11'].min())
print(df_2021['tmax_anom_10_11'].max())

print(df_2023['tmax_anom_10_11'].min())
print(df_2023['tmax_anom_10_11'].max())
# Out:
# -65.98046582893892
# 140.25322956562047
# -49.87769986044278
# 166.95068300659

# %%
dest_crs = ccrs.AlbersEqualArea(central_longitude=-76.0, central_latitude=42.0,)

# %%
fig, axes = uplt.subplots(ncols=2, nrows=3, figsize=('140mm','155mm'), proj=dest_crs, 
                          facecolor='white', fontsize=12, share=False)

axes.format(abc='A.', abcloc='ul')

norm_defol = plt.colors.Normalize(vmin=0, vmax=0.6)
cmap_defol = uplt.Colormap('Reds')

norm_prcp = plt.colors.Normalize(vmin=-200, vmax=200)
cmap_prcp = uplt.Colormap('NegPos_r')

norm_tmax = plt.colors.Normalize(vmin=-150, vmax=150)
cmap_tmax = uplt.Colormap('NegPos')

for i, forest in enumerate([df_2021, df_2023]):
    for row in forest.itertuples():
        defol = cfeature.ShapelyFeature(
            row.geometry,
            ccrs.epsg(5070),
            facecolor=cmap_defol(norm_defol(row.defol_forest_3)),
            edgecolor=cmap_defol(norm_defol(row.defol_forest_3)))
        axes[i].add_feature(defol)

        prcp = cfeature.ShapelyFeature(
            row.geometry,
            ccrs.epsg(5070),
            facecolor=cmap_prcp(norm_prcp(row.prcp_anom_10_12)),
            edgecolor=cmap_prcp(norm_prcp(row.prcp_anom_10_12)))
        axes[i + 2].add_feature(prcp)

        tmax = cfeature.ShapelyFeature(
            row.geometry,
            ccrs.epsg(5070),
            facecolor=cmap_tmax(norm_tmax(row.tmax_anom_10_11)),
            edgecolor=cmap_tmax(norm_tmax(row.tmax_anom_10_11)))
        axes[i + 4].add_feature(tmax)

axes[1].colorbar(cmap_defol, vmin=norm_defol.vmin, vmax=norm_defol.vmax)
axes[3].colorbar(cmap_prcp, vmin=norm_prcp.vmin, vmax=norm_prcp.vmax)
axes[5].colorbar(cmap_tmax, vmin=norm_tmax.vmin, vmax=norm_tmax.vmax)
        
axes.set_extent([-80, -71.7, 40.3, 45], crs=ccrs.PlateCarree())
axes.add_feature(cfeature.STATES)
axes.format(
    toplabels=('2021', '2023'),
    toplabels_kw={'size':'14', 'ha':'center'},
    leftlabels=('Defoliation\nExtent', 
                'Precipitation\nAnomaly', 
                'Max. Temperature\nAnomaly'),
    leftlabels_kw={'size':'12', 'ma':'center'},
    grid=False, 
    facecolor='white')

fig.savefig('./Figures/LagMaps/AnomalyPlots.png')
# Out:
# Figure(nrows=3, ncols=2, figwidth=np.float64(5.51), figheight=np.float64(6.1))

# %%
fig, axes = uplt.subplots(ncols=3, nrows=4, figsize=('190mm','220mm'), proj=dest_crs, 
                          facecolor='white', fontsize=12, share=False)

axes.format(abc='A.', abcloc='ul')

norm_defol = plt.colors.Normalize(vmin=0, vmax=0.1)
cmap_defol = uplt.Colormap('Reds3')

norm_prcp = plt.colors.Normalize(vmin=-200, vmax=200)
cmap_prcp = uplt.Colormap('NegPos_r')

norm_tmax = plt.colors.Normalize(vmin=-150, vmax=150)
cmap_tmax = uplt.Colormap('NegPos')

for i, forest in enumerate([df_2020, df_2021, df_2022, df_2023]):
    for row in forest.itertuples():
        defol = cfeature.ShapelyFeature(
            row.geometry,
            ccrs.epsg(5070),
            facecolor=cmap_defol(norm_defol(row.pred_defol_forest_3)),
            edgecolor=cmap_defol(norm_defol(row.pred_defol_forest_3)))
        axes[3*i].add_feature(defol)

        prcp = cfeature.ShapelyFeature(
            row.geometry,
            ccrs.epsg(5070),
            facecolor=cmap_prcp(norm_prcp(row.prcp_anom_10_12)),
            edgecolor=cmap_prcp(norm_prcp(row.prcp_anom_10_12)))
        axes[3*i + 1].add_feature(prcp)

        tmax = cfeature.ShapelyFeature(
            row.geometry,
            ccrs.epsg(5070),
            facecolor=cmap_tmax(norm_tmax(row.tmax_anom_10_11)),
            edgecolor=cmap_tmax(norm_tmax(row.tmax_anom_10_11)))
        axes[3*i + 2].add_feature(tmax)

axes[9].colorbar(cmap_defol, loc='b', length=0.9, vmin=norm_defol.vmin, vmax=norm_defol.vmax)
axes[10].colorbar(cmap_prcp, loc='b', length=0.9, vmin=norm_prcp.vmin, vmax=norm_prcp.vmax)
axes[11].colorbar(cmap_tmax, loc='b', length=0.9, vmin=norm_tmax.vmin, vmax=norm_tmax.vmax)
        
axes.set_extent([-80, -71.7, 40.3, 45], crs=ccrs.PlateCarree())
axes.add_feature(cfeature.STATES)
axes.format(
    toplabels=('Defoliation\nRisk', 
                'Precipitation\nAnomaly', 
                'Max. Temperature\nAnomaly'),
    toplabels_kw={'size':'14', 'ha':'center'},
    leftlabels=('2020', '2021', '2022', '2023'),
    leftlabels_kw={'size':'12', 'ma':'center'},
    grid=False, 
    facecolor='white')

fig.savefig('./Figures/LagMaps/PredAnomalyPlots.png')
# Out:
# Figure(nrows=4, ncols=3, figwidth=np.float64(7.48), figheight=np.float64(8.66))

# %% [markdown]
# # For Presentation

# %%
fig, axes = uplt.subplots(ncols=4, nrows=2, proj=dest_crs, 
                          facecolor='white', fontsize=12, share=False)

axes.format(abc='A.', abcloc='ul')

norm_defol = plt.colors.Normalize(vmin=0, vmax=0.6)
cmap_defol = uplt.Colormap('Reds3')

norm_pred_defol = plt.colors.Normalize(vmin=0, vmax=0.1)
cmap_pred_defol = uplt.Colormap('Reds3')

norm_prcp = plt.colors.Normalize(vmin=-200, vmax=200)
cmap_prcp = uplt.Colormap('NegPos_r')

norm_tmax = plt.colors.Normalize(vmin=-150, vmax=150)
cmap_tmax = uplt.Colormap('NegPos')

for i, forest in enumerate([df_2022, df_2023]):
    for row in forest.itertuples():
        defol = cfeature.ShapelyFeature(
            row.geometry,
            ccrs.epsg(5070),
            facecolor=cmap_defol(norm_defol(row.defol_forest_3)),
            edgecolor=cmap_defol(norm_defol(row.defol_forest_3)))
        axes[4*i].add_feature(defol)
        
        pred_defol = cfeature.ShapelyFeature(
            row.geometry,
            ccrs.epsg(5070),
            facecolor=cmap_pred_defol(norm_pred_defol(row.pred_defol_forest_3)),
            edgecolor=cmap_pred_defol(norm_pred_defol(row.pred_defol_forest_3)))
        axes[4*i + 1].add_feature(pred_defol)

        prcp = cfeature.ShapelyFeature(
            row.geometry,
            ccrs.epsg(5070),
            facecolor=cmap_prcp(norm_prcp(row.prcp_anom_10_12)),
            edgecolor=cmap_prcp(norm_prcp(row.prcp_anom_10_12)))
        axes[4*i + 2].add_feature(prcp)

        tmax = cfeature.ShapelyFeature(
            row.geometry,
            ccrs.epsg(5070),
            facecolor=cmap_tmax(norm_tmax(row.tmax_anom_10_11)),
            edgecolor=cmap_tmax(norm_tmax(row.tmax_anom_10_11)))
        axes[4*i + 3].add_feature(tmax)

axes[4].colorbar(cmap_defol, loc='b', length=0.9, vmin=norm_defol.vmin, vmax=norm_defol.vmax)
axes[5].colorbar(cmap_pred_defol, loc='b', length=0.9, vmin=norm_pred_defol.vmin, vmax=norm_pred_defol.vmax)
axes[6].colorbar(cmap_prcp, loc='b', length=0.9, vmin=norm_prcp.vmin, vmax=norm_prcp.vmax)
axes[7].colorbar(cmap_tmax, loc='b', length=0.9, vmin=norm_tmax.vmin, vmax=norm_tmax.vmax)
        
axes.set_extent([-80, -71.7, 40.3, 45], crs=ccrs.PlateCarree())
axes.add_feature(cfeature.STATES)
axes.format(
    toplabels=('Actual\nDefoliation Extent',
                'Predicted\nDefoliation Extent', 
                'Precipitation\nAnomaly', 
                'Max. Temperature\nAnomaly'),
    toplabels_kw={'size':'14', 'ha':'center'},
    leftlabels=('2022', '2023'),
    leftlabels_kw={'size':'12', 'ma':'center'},
    grid=False, 
    facecolor='white')

fig.savefig('./Figures/LagMaps/PresentationComparison.png')
# Out:
# Figure(nrows=2, ncols=4, refwidth=np.float64(2.5))
