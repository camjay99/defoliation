# %%
import proplot as pplt
import matplotlib as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Mt. Pleasant

# %% [markdown]
# ## Individual Plots with threshold markers

# %% [markdown]
# ### Sentinel-2 unscaled

# %%
sentinel2_unscaled_mp = pd.read_csv('./Data/ROC/ROC_Mt_Pleasant_Sentinel2_unscaled_2021.csv')
fig, ax = pplt.subplots()
ax.plot(sentinel2_unscaled_mp['FPR'], sentinel2_unscaled_mp['TPR'])
c1 = ax.scatter(sentinel2_unscaled_mp['FPR'], sentinel2_unscaled_mp['TPR'], c=sentinel2_unscaled_mp['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Mt_Pleasant_Sentinel2_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Sentinel-2

# %%
sentinel2_mp = pd.read_csv('./Data/ROC/ROC_Mt_Pleasant_Sentinel2_2021.csv')
fig, ax = pplt.subplots()
ax.plot(sentinel2_mp['FPR'], sentinel2_mp['TPR'])
c1 = ax.scatter(sentinel2_mp['FPR'], sentinel2_mp['TPR'], c=sentinel2_mp['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Mt_Pleasant_Sentinel2_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Landsat unscaled

# %%
landsat_unscaled_mp = pd.read_csv('./Data/ROC/ROC_Mt_Pleasant_Landsat_unscaled_2021.csv')
fig, ax = pplt.subplots()
ax.plot(landsat_unscaled_mp['FPR'], landsat_unscaled_mp['TPR'])
c1 = ax.scatter(landsat_unscaled_mp['FPR'], landsat_unscaled_mp['TPR'], c=landsat_unscaled_mp['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Mt_Pleasant_Landsat_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Landsat

# %%
landsat_mp = pd.read_csv('./Data/ROC/ROC_Mt_Pleasant_Landsat_2021.csv')
fig, ax = pplt.subplots()
ax.plot(landsat_mp['FPR'], landsat_mp['TPR'])
c1 = ax.scatter(landsat_mp['FPR'], landsat_mp['TPR'], c=landsat_mp['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Mt_Pleasant_Landsat_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### MODIS unscaled

# %%
modis_unscaled_mp = pd.read_csv('./Data/ROC/ROC_Mt_Pleasant_MODIS_unscaled_2021.csv')
fig, ax = pplt.subplots()
ax.plot(modis_unscaled_mp['FPR'], modis_unscaled_mp['TPR'])
c1 = ax.scatter(modis_unscaled_mp['FPR'], modis_unscaled_mp['TPR'], c=modis_unscaled_mp['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Mt_Pleasant_MODIS_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### MODIS

# %%
modis_mp = pd.read_csv('./Data/ROC/ROC_Mt_Pleasant_MODIS_2021.csv')
fig, ax = pplt.subplots()
ax.plot(modis_mp['FPR'], modis_mp['TPR'])
c1 = ax.scatter(modis_mp['FPR'], modis_mp['TPR'], c=modis_mp['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Mt_Pleasant_MODIS_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ## ROC comparison plots

# %% [markdown]
# ### With threshold markers

# %%
fig, ax = pplt.subplots()

# Sentinel-2 unscaled
m1 = ax.plot(sentinel2_unscaled_mp['FPR'], sentinel2_unscaled_mp['TPR'], label='Sentinel-2 unscaled')
ax.scatter(sentinel2_unscaled_mp['FPR'], sentinel2_unscaled_mp['TPR'], c=sentinel2_unscaled_mp['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Sentinel-2
m2 = ax.plot(sentinel2_mp['FPR'], sentinel2_mp['TPR'], label='Sentinel-2')
ax.scatter(sentinel2_mp['FPR'], sentinel2_mp['TPR'], c=sentinel2_mp['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat unscaled
m3 = ax.plot(landsat_unscaled_mp['FPR'], landsat_unscaled_mp['TPR'], label='Landsat unscaled')
ax.scatter(landsat_unscaled_mp['FPR'], landsat_unscaled_mp['TPR'], c=landsat_unscaled_mp['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat
m4 = ax.plot(landsat_mp['FPR'], landsat_mp['TPR'], label='Landsat')
ax.scatter(landsat_mp['FPR'], landsat_mp['TPR'], c=landsat_mp['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS unscaled
m5 = ax.plot(modis_unscaled_mp['FPR'], modis_unscaled_mp['TPR'], label='MODIS unscaled')
ax.scatter(modis_unscaled_mp['FPR'], modis_unscaled_mp['TPR'], c=modis_unscaled_mp['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS
m6 = ax.plot(modis_mp['FPR'], modis_mp['TPR'], label='MODIS')
ax.scatter(modis_mp['FPR'], modis_mp['TPR'], c=modis_mp['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

ax.plot([0, 1], [0, 1])
ax.format(xlim=[0, 1])
ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')

fig.savefig('./Figures/ROC/Mt_Pleasant_all_methods_ROC_threshold.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Without Threshold Markers

# %%
def create_multifactor_legend(fig, ax, labels_props, legend_kw):
    # labels_props is a dictionary in the form of
    # {<label> : {<property> : <value>}, ...}
    for label in labels_props:
        # Create empty artists to record in legend
        ax.plot([], [], label=label, **labels_props[label])
    ax.legend(**legend_kw)

# %%
fig, ax = pplt.subplots()

# Define plotting properties
props = {'Satellite'      : {'linestyle' : 'None'},
         'Sentinel-2'     : {'color' : 'orange'},
         'Landsat'        : {'color' : 'purple'},
         'MODIS'          : {'color' : 'green'},
         'Method'         : {'linestyle' : 'None'},
         'No Rescaling'   : {'color' : 'black',
                             'linestyle' : 'solid'},
         'With Rescaling' : {'color' : 'black',
                             'linestyle' : 'dashed'}}

# Sentinel-2 unscaled
ax.plot(sentinel2_unscaled_mp['FPR'], sentinel2_unscaled_mp['TPR'], label='', color='orange')

# Sentinel-2
ax.plot(sentinel2_mp['FPR'], sentinel2_mp['TPR'], label='', color='orange', linestyle='dashed')

# Landsat unscaled
ax.plot(landsat_unscaled_mp['FPR'], landsat_unscaled_mp['TPR'], label='', color='purple')

# Landsat
ax.plot(landsat_mp['FPR'], landsat_mp['TPR'], label='', color='purple', linestyle='dashed')

# MODIS unscaled
ax.plot(modis_unscaled_mp['FPR'], modis_unscaled_mp['TPR'], label='', color='green')

# MODIS
ax.plot(modis_mp['FPR'], modis_mp['TPR'], label='', color='green', linestyle='dashed')

ax.plot([0, 1], [0, 1])
ax.format(xlim=[0, 1])
#ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')
             
create_multifactor_legend(fig, ax, props, {'ncols':1, 'loc':'r'})

fig.savefig('./Figures/ROC/Mt_Pleasant_all_methods_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# # Allegheny

# %% [markdown]
# ## Individual Plots with threshold markers

# %% [markdown]
# ### Sentinel-2 unscaled

# %%
sentinel2_unscaled_alle = pd.read_csv('./Data/ROC/ROC_Allegheny_Sentinel2_unscaled_2021.csv')
fig, ax = pplt.subplots()
ax.plot(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'])
c1 = ax.scatter(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], c=sentinel2_unscaled_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Allegheny_Sentinel2_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Sentinel-2

# %%
sentinel2_alle = pd.read_csv('./Data/ROC/ROC_Allegheny_Sentinel2_2021.csv')
fig, ax = pplt.subplots()
ax.plot(sentinel2_alle['FPR'], sentinel2_alle['TPR'])
c1 = ax.scatter(sentinel2_alle['FPR'], sentinel2_alle['TPR'], c=sentinel2_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Allegheny_Sentinel2_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Landsat unscaled

# %%
landsat_unscaled_alle = pd.read_csv('./Data/ROC/ROC_Allegheny_Landsat_unscaled_2021.csv')
fig, ax = pplt.subplots()
ax.plot(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'])
c1 = ax.scatter(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], c=landsat_unscaled_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Allegheny_Landsat_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Landsat

# %%
landsat_alle = pd.read_csv('./Data/ROC/ROC_Allegheny_Landsat_2021.csv')
fig, ax = pplt.subplots()
ax.plot(landsat_alle['FPR'], landsat_alle['TPR'])
c1 = ax.scatter(landsat_alle['FPR'], landsat_alle['TPR'], c=landsat_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Allegheny_Landsat_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### MODIS unscaled

# %%
modis_unscaled_alle = pd.read_csv('./Data/ROC/ROC_Allegheny_MODIS_unscaled_2021.csv')
fig, ax = pplt.subplots()
ax.plot(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'])
c1 = ax.scatter(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], c=modis_unscaled_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Allegheny_MODIS_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### MODIS

# %%
modis_alle = pd.read_csv('./Data/ROC/ROC_Allegheny_MODIS_2021.csv')
fig, ax = pplt.subplots()
ax.plot(modis_alle['FPR'], modis_alle['TPR'])
c1 = ax.scatter(modis_alle['FPR'], modis_alle['TPR'], c=modis_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Allegheny_MODIS_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ## ROC comparison plots

# %% [markdown]
# ### With threshold markers

# %%
fig, ax = pplt.subplots()

# Sentinel-2 unscaled
m1 = ax.plot(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], label='Sentinel-2 unscaled')
ax.scatter(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], c=sentinel2_unscaled_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Sentinel-2
m2 = ax.plot(sentinel2_alle['FPR'], sentinel2_alle['TPR'], label='Sentinel-2')
ax.scatter(sentinel2_alle['FPR'], sentinel2_alle['TPR'], c=sentinel2_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat unscaled
m3 = ax.plot(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], label='Landsat unscaled')
ax.scatter(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], c=landsat_unscaled_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat
m4 = ax.plot(landsat_alle['FPR'], landsat_alle['TPR'], label='Landsat')
ax.scatter(landsat_alle['FPR'], landsat_alle['TPR'], c=landsat_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS unscaled
m5 = ax.plot(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], label='MODIS unscaled')
ax.scatter(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], c=modis_unscaled_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS
m6 = ax.plot(modis_alle['FPR'], modis_alle['TPR'], label='MODIS')
ax.scatter(modis_alle['FPR'], modis_alle['TPR'], c=modis_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

ax.plot([0, 1], [0, 1])
ax.format(xlim=[0, 1])
ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')

fig.savefig('./Figures/ROC/Allegheny_all_methods_ROC_threshold.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Without threshold markers

# %%
fig, ax = pplt.subplots()

# Define plotting properties
props = {'Satellite'      : {'linestyle' : 'None'},
         'Sentinel-2'     : {'color' : 'orange'},
         'Landsat'        : {'color' : 'purple'},
         'MODIS'          : {'color' : 'green'},
         'Method'         : {'linestyle' : 'None'},
         'No Rescaling'   : {'color' : 'black',
                             'linestyle' : 'solid'},
         'With Rescaling' : {'color' : 'black',
                             'linestyle' : 'dashed'}}

# Sentinel-2 unscaled
ax.plot(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], label='', color='orange')

# Sentinel-2
ax.plot(sentinel2_alle['FPR'], sentinel2_alle['TPR'], label='', color='orange', linestyle='dashed')

# Landsat unscaled
ax.plot(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], label='', color='purple')

# Landsat
ax.plot(landsat_alle['FPR'], landsat_alle['TPR'], label='', color='purple', linestyle='dashed')

# MODIS unscaled
ax.plot(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], label='', color='green')

# MODIS
ax.plot(modis_alle['FPR'], modis_alle['TPR'], label='', color='green', linestyle='dashed')

ax.plot([0, 1], [0, 1])
ax.format(xlim=[0, 1])
#ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')
             
create_multifactor_legend(fig, ax, props, {'ncols':1, 'loc':'r'})

fig.savefig('./Figures/ROC/Allegheny_all_methods_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# # Arnot Forest

# %% [markdown]
# ## Individual Plots with threshold markers

# %% [markdown]
# ### Sentinel-2 unscaled

# %%
sentinel2_unscaled_alle = pd.read_csv('./Data/ROC/ROC_Arnot_Forest_Sentinel2_unscaled_2022.csv')
fig, ax = pplt.subplots()
ax.plot(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'])
c1 = ax.scatter(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], c=sentinel2_unscaled_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Arnot_Forest_Sentinel2_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Sentinel-2

# %%
sentinel2_alle = pd.read_csv('./Data/ROC/ROC_Arnot_Forest_Sentinel2_2022.csv')
fig, ax = pplt.subplots()
ax.plot(sentinel2_alle['FPR'], sentinel2_alle['TPR'])
c1 = ax.scatter(sentinel2_alle['FPR'], sentinel2_alle['TPR'], c=sentinel2_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Arnot_Forest_Sentinel2_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Landsat unscaled

# %%
landsat_unscaled_alle = pd.read_csv('./Data/ROC/ROC_Arnot_Forest_Landsat_unscaled_2022.csv')
fig, ax = pplt.subplots()
ax.plot(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'])
c1 = ax.scatter(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], c=landsat_unscaled_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Arnot_Forest_Landsat_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Landsat

# %%
landsat_alle = pd.read_csv('./Data/ROC/ROC_Arnot_Forest_Landsat_2022.csv')
fig, ax = pplt.subplots()
ax.plot(landsat_alle['FPR'], landsat_alle['TPR'])
c1 = ax.scatter(landsat_alle['FPR'], landsat_alle['TPR'], c=landsat_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Arnot_Forest_Landsat_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### MODIS unscaled

# %%
modis_unscaled_alle = pd.read_csv('./Data/ROC/ROC_Arnot_Forest_MODIS_unscaled_2022.csv')
fig, ax = pplt.subplots()
ax.plot(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'])
c1 = ax.scatter(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], c=modis_unscaled_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Arnot_Forest_MODIS_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### MODIS

# %%
modis_alle = pd.read_csv('./Data/ROC/ROC_Arnot_Forest_MODIS_2022.csv')
fig, ax = pplt.subplots()
ax.plot(modis_alle['FPR'], modis_alle['TPR'])
c1 = ax.scatter(modis_alle['FPR'], modis_alle['TPR'], c=modis_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Arnot_Forest_MODIS_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ## ROC comparison plots

# %% [markdown]
# ### With threshold markers

# %%
fig, ax = pplt.subplots()

# Sentinel-2 unscaled
m1 = ax.plot(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], label='Sentinel-2 unscaled')
ax.scatter(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], c=sentinel2_unscaled_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Sentinel-2
m2 = ax.plot(sentinel2_alle['FPR'], sentinel2_alle['TPR'], label='Sentinel-2')
ax.scatter(sentinel2_alle['FPR'], sentinel2_alle['TPR'], c=sentinel2_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat unscaled
m3 = ax.plot(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], label='Landsat unscaled')
ax.scatter(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], c=landsat_unscaled_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat
m4 = ax.plot(landsat_alle['FPR'], landsat_alle['TPR'], label='Landsat')
ax.scatter(landsat_alle['FPR'], landsat_alle['TPR'], c=landsat_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS unscaled
m5 = ax.plot(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], label='MODIS unscaled')
ax.scatter(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], c=modis_unscaled_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS
m6 = ax.plot(modis_alle['FPR'], modis_alle['TPR'], label='MODIS')
ax.scatter(modis_alle['FPR'], modis_alle['TPR'], c=modis_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

ax.plot([0, 1], [0, 1])
ax.format(xlim=[0, 1])
ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')

fig.savefig('./Figures/ROC/Arnot_Forest_all_methods_ROC_threshold.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Without threshold markers

# %%
fig, ax = pplt.subplots()

# Define plotting properties
props = {'Satellite'      : {'linestyle' : 'None'},
         'Sentinel-2'     : {'color' : 'orange'},
         'Landsat'        : {'color' : 'purple'},
         'MODIS'          : {'color' : 'green'},
         'Method'         : {'linestyle' : 'None'},
         'No Rescaling'   : {'color' : 'black',
                             'linestyle' : 'solid'},
         'With Rescaling' : {'color' : 'black',
                             'linestyle' : 'dashed'}}

# Sentinel-2 unscaled
ax.plot(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], label='', color='orange')

# Sentinel-2
ax.plot(sentinel2_alle['FPR'], sentinel2_alle['TPR'], label='', color='orange', linestyle='dashed')

# Landsat unscaled
ax.plot(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], label='', color='purple')

# Landsat
ax.plot(landsat_alle['FPR'], landsat_alle['TPR'], label='', color='purple', linestyle='dashed')

# MODIS unscaled
ax.plot(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], label='', color='green')

# MODIS
ax.plot(modis_alle['FPR'], modis_alle['TPR'], label='', color='green', linestyle='dashed')

ax.plot([0, 1], [0, 1])
ax.format(xlim=[0, 1])
#ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')
             
create_multifactor_legend(fig, ax, props, {'ncols':1, 'loc':'r'})

fig.savefig('./Figures/ROC/Arnot_Forest_all_methods_ROC.svg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 36
#      33 ax.format(xlim=[0, 1])
#      34 #ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')
# ---> 36 create_multifactor_legend(fig, ax, props, {'ncols':1, 'loc':'r'})
#      38 fig.savefig('./Figures/ROC/Arnot_Forest_all_methods_ROC.svg')
#
# NameError: name 'create_multifactor_legend' is not defined
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# # Turkey Point

# %% [markdown]
# ## Individual Plots with threshold markers

# %% [markdown]
# ### Sentinel-2 unscaled

# %%
sentinel2_unscaled_alle = pd.read_csv('./Data/ROC/ROC_Turkey_Point_Sentinel2_unscaled_2021.csv')
fig, ax = pplt.subplots()
ax.plot(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'])
c1 = ax.scatter(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], c=sentinel2_unscaled_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Turkey_Point_Sentinel2_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Sentinel-2

# %%
sentinel2_alle = pd.read_csv('./Data/ROC/ROC_Turkey_Point_Sentinel2_2021.csv')
fig, ax = pplt.subplots()
ax.plot(sentinel2_alle['FPR'], sentinel2_alle['TPR'])
c1 = ax.scatter(sentinel2_alle['FPR'], sentinel2_alle['TPR'], c=sentinel2_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Turkey_Point_Sentinel2_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Landsat unscaled

# %%
landsat_unscaled_alle = pd.read_csv('./Data/ROC/ROC_Turkey_Point_Landsat_unscaled_2021.csv')
fig, ax = pplt.subplots()
ax.plot(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'])
c1 = ax.scatter(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], c=landsat_unscaled_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Turkey_Point_Landsat_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Landsat

# %%
landsat_alle = pd.read_csv('./Data/ROC/ROC_Turkey_Point_Landsat_2021.csv')
fig, ax = pplt.subplots()
ax.plot(landsat_alle['FPR'], landsat_alle['TPR'])
c1 = ax.scatter(landsat_alle['FPR'], landsat_alle['TPR'], c=landsat_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Turkey_Point_Landsat_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### MODIS unscaled

# %%
modis_unscaled_alle = pd.read_csv('./Data/ROC/ROC_Turkey_Point_MODIS_unscaled_2021.csv')
fig, ax = pplt.subplots()
ax.plot(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'])
c1 = ax.scatter(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], c=modis_unscaled_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Turkey_Point_MODIS_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### MODIS

# %%
modis_alle = pd.read_csv('./Data/ROC/ROC_Turkey_Point_MODIS_2021.csv')
fig, ax = pplt.subplots()
ax.plot(modis_alle['FPR'], modis_alle['TPR'])
c1 = ax.scatter(modis_alle['FPR'], modis_alle['TPR'], c=modis_alle['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Turkey_Point_MODIS_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ## ROC comparison plots

# %% [markdown]
# ### With threshold markers

# %%
fig, ax = pplt.subplots()

# Sentinel-2 unscaled
m1 = ax.plot(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], label='Sentinel-2 unscaled')
ax.scatter(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], c=sentinel2_unscaled_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Sentinel-2
m2 = ax.plot(sentinel2_alle['FPR'], sentinel2_alle['TPR'], label='Sentinel-2')
ax.scatter(sentinel2_alle['FPR'], sentinel2_alle['TPR'], c=sentinel2_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat unscaled
m3 = ax.plot(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], label='Landsat unscaled')
ax.scatter(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], c=landsat_unscaled_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat
m4 = ax.plot(landsat_alle['FPR'], landsat_alle['TPR'], label='Landsat')
ax.scatter(landsat_alle['FPR'], landsat_alle['TPR'], c=landsat_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS unscaled
m5 = ax.plot(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], label='MODIS unscaled')
ax.scatter(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], c=modis_unscaled_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS
m6 = ax.plot(modis_alle['FPR'], modis_alle['TPR'], label='MODIS')
ax.scatter(modis_alle['FPR'], modis_alle['TPR'], c=modis_alle['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

ax.plot([0, 1], [0, 1])
ax.format(xlim=[0, 1])
ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')

fig.savefig('./Figures/ROC/Turkey_Point_all_methods_ROC_threshold.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Without threshold markers

# %%
fig, ax = pplt.subplots()

# Define plotting properties
props = {'Satellite'      : {'linestyle' : 'None'},
         'Sentinel-2'     : {'color' : 'orange'},
         'Landsat'        : {'color' : 'purple'},
         'MODIS'          : {'color' : 'green'},
         'Method'         : {'linestyle' : 'None'},
         'No Rescaling'   : {'color' : 'black',
                             'linestyle' : 'solid'},
         'With Rescaling' : {'color' : 'black',
                             'linestyle' : 'dashed'}}

# Sentinel-2 unscaled
ax.plot(sentinel2_unscaled_alle['FPR'], sentinel2_unscaled_alle['TPR'], label='', color='orange')

# Sentinel-2
ax.plot(sentinel2_alle['FPR'], sentinel2_alle['TPR'], label='', color='orange', linestyle='dashed')

# Landsat unscaled
ax.plot(landsat_unscaled_alle['FPR'], landsat_unscaled_alle['TPR'], label='', color='purple')

# Landsat
ax.plot(landsat_alle['FPR'], landsat_alle['TPR'], label='', color='purple', linestyle='dashed')

# MODIS unscaled
ax.plot(modis_unscaled_alle['FPR'], modis_unscaled_alle['TPR'], label='', color='green')

# MODIS
ax.plot(modis_alle['FPR'], modis_alle['TPR'], label='', color='green', linestyle='dashed')

ax.plot([0, 1], [0, 1])
ax.format(xlim=[0, 1])
#ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')
             
create_multifactor_legend(fig, ax, props, {'ncols':1, 'loc':'r'})

fig.savefig('./Figures/ROC/Turkey_Point_all_methods_ROC.svg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 36
#      33 ax.format(xlim=[0, 1])
#      34 #ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')
# ---> 36 create_multifactor_legend(fig, ax, props, {'ncols':1, 'loc':'r'})
#      38 fig.savefig('./Figures/ROC/Turkey_Point_all_methods_ROC.svg')
#
# NameError: name 'create_multifactor_legend' is not defined
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# # Combined

# %%
def combine_sites(method_name):
    allegheny_count = 198
    mt_pleasant_count = 196
    arnot_forest_count = 195
    turkey_point_count = 200

    allegheny = pd.read_csv(f'./Data/ROC/ROC_Allegheny_{method_name}_2021.csv')
    mt_pleasant = pd.read_csv(f'./Data/ROC/ROC_Mt_Pleasant_{method_name}_2021.csv')
    arnot_forest = pd.read_csv(f'./Data/ROC/ROC_Arnot_Forest_{method_name}_2022.csv')
    turkey_point = pd.read_csv(f'./Data/ROC/ROC_Turkey_Point_{method_name}_2021.csv')
    combined = ((allegheny*allegheny_count + mt_pleasant*mt_pleasant_count
                           + arnot_forest*arnot_forest_count + turkey_point*turkey_point_count)
                          /(allegheny_count + mt_pleasant_count + arnot_forest_count + turkey_point_count))
    
    return combined

# %%
sentinel2_unscaled = combine_sites('Sentinel2_unscaled')
sentinel2 = combine_sites('Sentinel2')
landsat_unscaled = combine_sites('Landsat_unscaled')
landsat = combine_sites('Landsat')
modis_unscaled = combine_sites('MODIS_unscaled')
modis = combine_sites('MODIS')

# %% [markdown]
# ## Individual Plots with threshold markers

# %% [markdown]
# ### Sentinel-2 unscaled

# %%
fig, ax = pplt.subplots()
ax.plot(sentinel2_unscaled['FPR'], sentinel2_unscaled['TPR'])
c1 = ax.scatter(sentinel2_unscaled['FPR'], sentinel2_unscaled['TPR'], c=sentinel2_unscaled['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Combined_Sentinel2_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Sentinel-2

# %%
fig, ax = pplt.subplots()
ax.plot(sentinel2['FPR'], sentinel2['TPR'])
c1 = ax.scatter(sentinel2['FPR'], sentinel2['TPR'], c=sentinel2['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Combined_Sentinel2_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Landsat unscaled

# %%
fig, ax = pplt.subplots()
ax.plot(landsat_unscaled['FPR'], landsat_unscaled['TPR'])
c1 = ax.scatter(landsat_unscaled['FPR'], landsat_unscaled['TPR'], c=landsat_unscaled['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Combined_Landsat_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Landsat

# %%
fig, ax = pplt.subplots()
ax.plot(landsat['FPR'], landsat['TPR'])
c1 = ax.scatter(landsat['FPR'], landsat['TPR'], c=landsat['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Combined_Landsat_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### MODIS unscaled

# %%
fig, ax = pplt.subplots()
ax.plot(modis_unscaled['FPR'], modis_unscaled['TPR'])
c1 = ax.scatter(modis_unscaled['FPR'], modis_unscaled['TPR'], c=modis_unscaled['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Combined_MODIS_unscaled_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### MODIS

# %%
fig, ax = pplt.subplots()
ax.plot(modis['FPR'], modis['TPR'])
c1 = ax.scatter(modis['FPR'], modis['TPR'], c=modis['threshold'], vmax=0.3, vmin=-0.4, cmap='cividis')

ax.format(xlim=[0, 1])
ax.colorbar(c1, title='Threshold', loc='lr')

fig.savefig('./Figures/ROC/Combined_MODIS_ROC.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ## ROC comparison plots

# %% [markdown]
# ### With threshold markers

# %%
fig, ax = pplt.subplots()

# Sentinel-2 unscaled
m1 = ax.plot(sentinel2_unscaled['FPR'], sentinel2_unscaled['TPR'], label='Sentinel-2 unscaled')
ax.scatter(sentinel2_unscaled['FPR'], sentinel2_unscaled['TPR'], c=sentinel2_unscaled['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Sentinel-2
m2 = ax.plot(sentinel2['FPR'], sentinel2['TPR'], label='Sentinel-2')
ax.scatter(sentinel2['FPR'], sentinel2['TPR'], c=sentinel2['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat unscaled
m3 = ax.plot(landsat_unscaled['FPR'], landsat_unscaled['TPR'], label='Landsat unscaled')
ax.scatter(landsat_unscaled['FPR'], landsat_unscaled['TPR'], c=landsat_unscaled['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat
m4 = ax.plot(landsat['FPR'], landsat['TPR'], label='Landsat')
ax.scatter(landsat['FPR'], landsat['TPR'], c=landsat['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS unscaled
m5 = ax.plot(modis_unscaled['FPR'], modis_unscaled['TPR'], label='MODIS unscaled')
ax.scatter(modis_unscaled['FPR'], modis_unscaled['TPR'], c=modis_unscaled['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS
m6 = ax.plot(modis['FPR'], modis['TPR'], label='MODIS')
ax.scatter(modis['FPR'], modis['TPR'], c=modis['threshold'], vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

ax.plot([0, 1], [0, 1])
ax.format(xlim=[0, 1])
ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')

fig.savefig('./Figures/ROC/Combined_all_methods_ROC_threshold.svg')
# Out:
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %% [markdown]
# ### Without threshold markers

# %%
fig, ax = pplt.subplots()

# Define plotting properties
props = {'Satellite'      : {'linestyle' : 'None'},
         'Sentinel-2'     : {'color' : 'orange'},
         'Landsat'        : {'color' : 'purple'},
         'MODIS'          : {'color' : 'green'},
         'Method'         : {'linestyle' : 'None'},
         'No Rescaling'   : {'color' : 'black',
                             'linestyle' : 'solid'},
         'With Rescaling' : {'color' : 'black',
                             'linestyle' : 'dashed'}}

# Sentinel-2 unscaled
ax.plot(sentinel2_unscaled['FPR'], sentinel2_unscaled['TPR'], label='', color='orange')

# Sentinel-2
ax.plot(sentinel2['FPR'], sentinel2['TPR'], label='', color='orange', linestyle='dashed')

# Landsat unscaled
ax.plot(landsat_unscaled['FPR'], landsat_unscaled['TPR'], label='', color='purple')

# Landsat
ax.plot(landsat['FPR'], landsat['TPR'], label='', color='purple', linestyle='dashed')

# MODIS unscaled
ax.plot(modis_unscaled['FPR'], modis_unscaled['TPR'], label='', color='green')

# MODIS
ax.plot(modis['FPR'], modis['TPR'], label='', color='green', linestyle='dashed')

# Optimal Points
TPRs = []
FPRs = []
for method in [sentinel2_unscaled, sentinel2, landsat_unscaled, landsat, modis_unscaled, modis]:
    index = np.argmin(np.sqrt((1 - method['TPR'])**2 + method['FPR']**2))
    TPRs.append(method['TPR'][index])
    FPRs.append(method['FPR'][index])
ax.scatter(FPRs, TPRs, c='black', zorder=10)

# # Zero Points
# TPRs = []
# FPRs = []
# for method in [sentinel2_unscaled, sentinel2, landsat_unscaled, landsat, modis_unscaled, modis]:
#     mask = method['threshold'] == 0
#     TPRs.append(method['TPR'][mask])
#     FPRs.append(method['FPR'][mask])
# ax.scatter(FPRs, TPRs, c='gray', zorder=10)

ax.plot([0, 1], [0, 1], color='black')
ax.format(xlim=[0, 1])
#ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')
             
create_multifactor_legend(fig, ax, props, {'ncols':1, 'loc':'r'})

fig.savefig('./Figures/ROC/Combined_all_methods_ROC.svg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 54
#      51 ax.format(xlim=[0, 1])
#      52 #ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')
# ---> 54 create_multifactor_legend(fig, ax, props, {'ncols':1, 'loc':'r'})
#      56 fig.savefig('./Figures/ROC/Combined_all_methods_ROC.svg')
#
# NameError: name 'create_multifactor_legend' is not defined
# Figure(nrows=1, ncols=1, refwidth=2.5)

# %%
fig, ax = pplt.subplots()

# Sentinel-2 unscaled
s2_un_point = np.argmin(np.sqrt((1 - sentinel2_unscaled['TPR'])**2 + sentinel2_unscaled['FPR']**2))
m1 = ax.plot(sentinel2_unscaled['FPR'], sentinel2_unscaled['TPR'], label='Sentinel-2 unscaled')
ax.scatter(sentinel2_unscaled['FPR'][s2_un_point], sentinel2_unscaled['TPR'][s2_un_point], c='black', vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Sentinel-2
s2_point = np.argmin(np.sqrt((1 - sentinel2['TPR'])**2 + sentinel2['FPR']**2))
m2 = ax.plot(sentinel2['FPR'], sentinel2['TPR'], label='Sentinel-2')
ax.scatter(sentinel2['FPR'][s2_point], sentinel2['TPR'][s2_point], c='black', vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat unscaled
ls_un_point = np.argmin(np.sqrt((1 - landsat_unscaled['TPR'])**2 + landsat_unscaled['FPR']**2))
m3 = ax.plot(landsat_unscaled['FPR'], landsat_unscaled['TPR'], label='Landsat unscaled')
ax.scatter(landsat_unscaled['FPR'][ls_un_point], landsat_unscaled['TPR'][ls_un_point], c='black', vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# Landsat
ls_point = np.argmin(np.sqrt((1 - landsat['TPR'])**2 + landsat['FPR']**2))
m4 = ax.plot(landsat['FPR'], landsat['TPR'], label='Landsat')
ax.scatter(landsat['FPR'][ls_point], landsat['TPR'][ls_point], c='black', vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS unscaled
ms_un_point = np.argmin(np.sqrt((1 - modis_unscaled['TPR'])**2 + modis_unscaled['FPR']**2))
m5 = ax.plot(modis_unscaled['FPR'], modis_unscaled['TPR'], label='MODIS unscaled')
ax.scatter(modis_unscaled['FPR'][ms_un_point], modis_unscaled['TPR'][ms_un_point], c='black', vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

# MODIS
ms_point = np.argmin(np.sqrt((1 - modis['TPR'])**2 + modis['FPR']**2))
m6 = ax.plot(modis['FPR'], modis['TPR'], label='MODIS')
ax.scatter(modis['FPR'][ms_point], modis['TPR'][ms_point], c='black', vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')

ax.plot([0, 1], [0, 1], color='black')
ax.plot([0, 1], [1, 0], linestyle='dashed', color='gray')
ax.format(xlim=[0, 1])
ax.legend([m1, m2, m3, m4, m5, m6], ncols=1, loc='r')
# Out:
# C:\Users\camer\AppData\Local\Temp\ipykernel_23080\3787391701.py:6: ProplotWarning: Ignoring unused keyword arg(s): {'cmap': 'cividis', 'vmin': -0.2, 'vmax': 0}
#   ax.scatter(sentinel2_unscaled['FPR'][s2_un_point], sentinel2_unscaled['TPR'][s2_un_point], c='black', vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')
# C:\Users\camer\AppData\Local\Temp\ipykernel_23080\3787391701.py:11: ProplotWarning: Ignoring unused keyword arg(s): {'cmap': 'cividis', 'vmin': -0.2, 'vmax': 0}
#   ax.scatter(sentinel2['FPR'][s2_point], sentinel2['TPR'][s2_point], c='black', vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')
# C:\Users\camer\AppData\Local\Temp\ipykernel_23080\3787391701.py:16: ProplotWarning: Ignoring unused keyword arg(s): {'cmap': 'cividis', 'vmin': -0.2, 'vmax': 0}
#   ax.scatter(landsat_unscaled['FPR'][ls_un_point], landsat_unscaled['TPR'][ls_un_point], c='black', vmax=0, vmin=-0.2, cmap='cividis', colorbar='lr')
# ...

# %%
print('Sentinel2 unscaled:', sentinel2_unscaled['threshold'][s2_un_point])
print('Sentinel2:', sentinel2['threshold'][s2_point])
print('Landsat unscaled:', landsat_unscaled['threshold'][ls_un_point])
print('Landsat:', landsat['threshold'][ls_point])
print('MODIS unscaled:', modis_unscaled['threshold'][ms_un_point])
print('MODIS:', modis['threshold'][ms_point])
# Out:
# Sentinel2 unscaled: -0.04
# Sentinel2: -0.01
# Landsat unscaled: -0.030000000000000002
# Landsat: 0.0
# MODIS unscaled: -0.025
# MODIS: -0.01

# %% [markdown]
# ## Allegheny/Mt. Pleasant Side-by-side

# %%
fig, axes = pplt.subplots(ncols=2)

# Mt. Pleasant
## Sentinel-2 unscaled
axes[0].plot(mt_pleasant_sentinel2_unscaled['FPR'], mt_pleasant_sentinel2_unscaled['TPR'], label='S2', color='orange', zorder=0)

## Landsat unscaled
axes[0].plot(mt_pleasant_landsat_unscaled['FPR'], mt_pleasant_landsat_unscaled['TPR'], label='LS', color='purple', zorder=2)

## MODIS unscaled
axes[0].plot(mt_pleasant_modis_unscaled['FPR'], mt_pleasant_modis_unscaled['TPR'], label='MODIS', color='green', zorder=4)

## Sentinel-2
axes[0].plot(mt_pleasant_sentinel2['FPR'], mt_pleasant_sentinel2['TPR'], label='S2 rescaled', color='orange', linestyle='dashed', zorder=1)

## Landsat
axes[0].plot(mt_pleasant_landsat['FPR'], mt_pleasant_landsat['TPR'], label='LS rescaled', color='purple', linestyle='dashed', zorder=2)

## MODIS
axes[0].plot(mt_pleasant_modis['FPR'], mt_pleasant_modis['TPR'], label='MODIS rescaled', color='green', linestyle='dashed', zorder=3)

axes[0].plot([0, 1], [0, 1], color='black')
axes[0].format(xlim=[0, 1], title='Mt. Pleasant')

# Allegheny
## Sentinel-2 unscaled
axes[1].plot(allegheny_sentinel2_unscaled['FPR'], allegheny_sentinel2_unscaled['TPR'], label='', color='orange')

## Sentinel-2
axes[1].plot(allegheny_sentinel2['FPR'], allegheny_sentinel2['TPR'], label='', color='orange', linestyle='dashed')

## Landsat unscaled
axes[1].plot(allegheny_landsat_unscaled['FPR'], allegheny_landsat_unscaled['TPR'], label='', color='purple')

## Landsat
axes[1].plot(allegheny_landsat['FPR'], allegheny_landsat['TPR'], label='', color='purple', linestyle='dashed')

## MODIS unscaled
axes[1].plot(allegheny_modis_unscaled['FPR'], allegheny_modis_unscaled['TPR'], label='', color='green')

## MODIS
axes[1].plot(allegheny_modis['FPR'], allegheny_modis['TPR'], label='', color='green', linestyle='dashed')

axes[1].plot([0, 1], [0, 1], color='black')
axes[1].format(xlim=[0, 1], title='Allegheny')

fig.legend(loc='b', ncols=3)

#fig.savefig('./Figures/ROC/Combined_all_methods_ROC.svg')
# Out:
# Figure(nrows=1, ncols=2, refwidth=2.5)

# %%
mt_pleasant_sentinel2_unscaled
# Out:
#      threshold  TPR  FPR        OA    Pos_UA    Neg_UA  valid_classified
# 0        0.300  1.0  1.0  0.265306  0.265306       NaN               196
# 1        0.295  1.0  1.0  0.265306  0.265306       NaN               196
# 2        0.290  1.0  1.0  0.265306  0.265306       NaN               196
# 3        0.285  1.0  1.0  0.265306  0.265306       NaN               196
# 4        0.280  1.0  1.0  0.265306  0.265306       NaN               196
# ..         ...  ...  ...       ...       ...       ...               ...
# 136     -0.380  0.0  0.0  0.734694       NaN  0.734694               196
# 137     -0.385  0.0  0.0  0.734694       NaN  0.734694               196
# 138     -0.390  0.0  0.0  0.734694       NaN  0.734694               196
# 139     -0.395  0.0  0.0  0.734694       NaN  0.734694               196
# 140     -0.400  0.0  0.0  0.734694       NaN  0.734694               196
#
# [141 rows x 7 columns]

# %% [markdown]
# ### Compute Area Under the Curve

# %%
sets = [allegheny_sentinel2_unscaled,
        mt_pleasant_sentinel2_unscaled,
        sentinel2_unscaled,
        allegheny_sentinel2,
        mt_pleasant_sentinel2,
        sentinel2,
        allegheny_landsat_unscaled,
        mt_pleasant_landsat_unscaled,
        landsat_unscaled,
        allegheny_landsat,
        mt_pleasant_landsat,
        landsat,
        allegheny_modis_unscaled,
        mt_pleasant_modis_unscaled,
        modis_unscaled,
        allegheny_modis,
        mt_pleasant_modis,
        modis]

names = ['Allegheny_S2_unscaled',
         'Mt_Pleasant_S2_unscaled',
         'S2_unscaled',
         'Allegheny_S2',
         'Mt_Pleasant_S2',
         'S2',
         'Allegheny_Landsat_unscaled',
         'Mt_Pleasant_Landsat_unscaled',
         'Landsat_unscaled',
         'Allegheny_Landsat',
         'Mt_Pleasant_Landsat',
         'Landsat',
         'Allegheny_MODIS_unscaled',
         'Mt_Pleasant_MODIS_unscaled',
         'MODIS_unscaled',
         'Allegheny_MODIS',
         'Mt_Pleasant_MODIS',
         'MODIS']

# %%
AUCs = []
for s in sets:
    FPR = s['FPR'].values
    TPR = s['TPR'].values

    FPR_dif = FPR[1:] - FPR[:-1]
    TPR_dif = (TPR[1:] + TPR[:-1])/2
    AUCs.append(np.sum(TPR_dif*FPR_dif)*-1)

# %%
AUCs
# Out:
# [0.9856927710843373,
#  0.9501869658119659,
#  0.9608071430946262,
#  0.8178652108433735,
#  0.8806089743589745,
#  0.8439992670720742,
#  0.8182503770739065,
#  0.8335820895522388,
#  0.8211662690874868,
#  0.7579185520361991,
#  0.751044776119403,
#  0.7517065653121483,
#  0.84043416514506,
#  0.6784032294236377,
#  0.767537894070928,
#  0.6773179143842565,
#  0.5920610002242656,
#  0.6334799317065793]

# %%
thresholds = []
OAs = []
Pos_PAs = []
Pos_UAs = []
Neg_PAs = []
Neg_UAs = []

for s in sets:
    opt_thresh = s['threshold'].values[np.argmin(np.sqrt((1 - s['TPR'])**2 + s['FPR']**2))]
    thresholds.append(opt_thresh)
    
    mask = s['threshold'] == opt_thresh
    OAs.append(s.loc[mask, 'OA'].values[0])
    Pos_PAs.append(s.loc[mask, 'TPR'].values[0])
    Pos_UAs.append(s.loc[mask, 'Pos_UA'].values[0])
    Neg_PAs.append(1 - s.loc[mask, 'FPR'].values[0])
    Neg_UAs.append(s.loc[mask, 'Neg_UA'].values[0])

results = pd.DataFrame(data={'Name': names,
                             'AUC': AUCs,
                             'threshold': thresholds,
                             'OA':OAs,
                             'Pos_PA': Pos_PAs,
                             'Neg_PA': Neg_PAs,
                             'Pos_UA': Pos_UAs,
                             'Neg_UA': Neg_UAs})

# %%
results
# Out:
#                             Name       AUC  threshold        OA    Pos_PA  \
# 0          Allegheny_S2_unscaled  0.985693     -0.035  0.944444  0.937500
# 1        Mt_Pleasant_S2_unscaled  0.950187     -0.070  0.887755  0.826923
# 2                    S2_unscaled  0.960807     -0.045  0.885787  0.898916
# 3                   Allegheny_S2  0.817865     -0.040  0.898990  0.718750
# 4                 Mt_Pleasant_S2  0.880609     -0.045  0.801020  0.788462
# 5                             S2  0.843999     -0.040  0.840102  0.762995
# 6     Allegheny_Landsat_unscaled  0.818250     -0.045  0.798507  0.764706
# 7   Mt_Pleasant_Landsat_unscaled  0.833582     -0.025  0.733696  0.820000
# 8               Landsat_unscaled  0.821166     -0.025  0.732513  0.821774
# 9              Allegheny_Landsat  0.757919     -0.020  0.701493  0.764706
# 10           Mt_Pleasant_Landsat  0.751045     -0.005  0.663043  0.700000
# 11                       Landsat  0.751707     -0.020  0.706698  0.652923
# ...

# %%
allegheny_sentinel2_unscaled[allegheny_sentinel2_unscaled['threshold'] == -0.045]
# Out:
#     threshold    TPR       FPR    Pos_UA   Neg_UA  valid_classified
# 69     -0.045  0.875  0.036145  0.823529  0.97561               198

# %%
print('Sentinel2 unscaled:', sentinel2_unscaled['threshold'][s2_un_point])
print('Sentinel2:', sentinel2['threshold'][s2_point])
print('Landsat unscaled:', landsat_unscaled['threshold'][ls_un_point])
print('Landsat:', landsat['threshold'][ls_point])
print('MODIS unscaled:', modis_unscaled['threshold'][ms_un_point])
print('MODIS:', modis['threshold'][ms_point])

# %%
allegheny_sentinel2_unscaled
mt_pleasant_sentinel2_unscaled
sentinel2_unscaled
allegheny_sentinel2
mt_pleasant_sentinel2
sentinel2
allegheny_landsat_unscaled
mt_pleasant_landsat_unscaled
landsat_unscaled
allegheny_landsat
mt_pleasant_landsat
landsat
allegheny_modis_unscaled
mt_pleasant_modis_unscaled
modis_unscaled
allegheny_modis
mt_pleasant_modis
modis
