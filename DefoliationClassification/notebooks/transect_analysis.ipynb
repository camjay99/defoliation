# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Plans
# * Modify defol_map to add additional information to analyses, such as date of minimum value, parameters of fit model, and model fit quality. Also calculate all defol indices at once.
# * Here, look at a transect date of minimum value through the map. Do we see a pattern between date and proximity to the center of the defoliation event?
